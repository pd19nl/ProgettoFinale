# %% [markdown]
# #Sorgente dati:
# https://situas.istat.it/web/#/apiDetail
#
# Dettaglio API
#
# Id report:
# 42
# Titolo report:
# Elenco Ripartizioni geografiche
# Inizio/fine validità report:
# 17/03/1861 - 11/01/1927
# Analisi temporale:
# DATA
# Ambito territoriale:
# Unità amministrative
# Unità territoriale:
# Ripartizione geografica
# Parametri necessari:
# pfun - pdata
# pfun: Id report
# pdata: data di estrazione (formato GG/MM/AAAA)
# Dati:
# https://situas-servizi.istat.it/publish/reportspooljson?pfun=42&pdata=17/03/1861
# Conteggio:
# https://situas-servizi.istat.it/publish/reportspooljsoncount?pfun=42&pdata=17/03/1861
# Metadati:
# https://situas-servizi.istat.it/publish/anagrafica_report_metadato_web?pfun=42&pdata=17/03/1861
#
#
# Struttura del documento
#
# {
#     "REPORT NAME": "Elenco Ripartizioni geografiche",
#     "REPORT DESCRIZIONE": "Il report restituisce la lista delle ripartizioni geografiche valide alla data selezionata e la relativa dimensione in termini di numerosità di unità territoriali sotto ordinate. Ciascuna ripartizione è identificata dalla denominazione e dal codice statistico.",
#     "COL_DETAILS": [
#         {
#             "COLNAME": "COD_RIP",
#             "LABEL": "Codice Ripartizione geografica",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Ripartizione geografica secondo la suddivisione del territorio nazionale in: 1) Nord-ovest, 2) Nord-est, 3) Centro, 4) Sud e 5) Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "DEN_RIP",
#             "LABEL": "Ripartizione geografica",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Denominazione della Ripartizione geografica  secondo la suddivisione del territorio nazionale in 5 ambiti: Nord-ovest, Nord-est, Centro, Sud e Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "N_COMP",
#             "LABEL": "Numero compartimenti",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Numero di compartimenti per ripartizione geografica",
#             "FORMATMASK": "999G999G999G999G999G999G990",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "N_PROV",
#             "LABEL": "Numero province",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Numero di province per ripartizione geografica",
#             "FORMATMASK": "999G999G999G999G999G999G990",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "N_CIR_DIS",
#             "LABEL": "Numero circondari/distretti",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Numero di circondari o distretti per ripartizione geografica",
#             "FORMATMASK": "999G999G999G999G999G999G990",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "N_COM",
#             "LABEL": "Numero comuni",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Numero di comuni per ripartizione geografica",
#             "FORMATMASK": "999G999G999G999G999G999G990",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         }
#     ]
# }

# %% [markdown]
# # attenzione report non disponibile
# unico report funzionante è quello indicato come esempio:
#
# https://situas-servizi.istat.it/publish/reportspooljson?pfun=42&pdata=17/03/1861

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali creati per questa fase


#aggiunto quando ho spostato i file in una cartella a parte
import sys
sys.path.append("./Moduli")

import Modulo_Fase_01 as fase1
#pip install reloading
#from reloading import reloading

# %%
# il report non va con i filtiri temporali
# fase1.RecuperaESalvaDatiIstat("42","Dati_RipartizioneGeografica","RipartizioneGeografica")
# si usa unico url che va
fase1.RecuperaESalvaDatiIstatUnicaRichiesta("https://situas-servizi.istat.it/publish/reportspooljson?pfun=42&pdata=17/03/1861",
                                            "Dati_RipartizioneGeografica","RipartizioneGeografica")
# Out:
# Avvio esportazione dati RipartizioneGeografica per anno
#    Recupero  dati https://situas-servizi.istat.it/publish/reportspooljson?pfun=42&pdata=17/03/1861
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_RipartizioneGeografica_All
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_RipartizioneGeografica_All.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_RipartizioneGeografica_All.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_RipartizioneGeografica_All.csv
# Fine esportazione dati {ambito} per anno

# %%
# non eseguita perche è possibile estrarre un solo report
#fase1.UnioneFileCsvPerAnno("Dati_RipartizioneGeografica")
