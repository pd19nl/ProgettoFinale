# %%
# =============================================================
# =============================================================
#
# librerie di base
import numpy as np
import pandas as pd

# =============================================================
# =============================================================
#
# librerie fase recupero dati
import requests as api

# =============================================================
# =============================================================
#
# gestione file e folder e so
import os
import io
from io import StringIO

# %%
# =============================================================
# =============================================================
#
# recupero struutura dati incidenti 
#
# =============================================================
# =============================================================

#per i primi 10 record si aggiunge la seguente query path: ?firstNObservations=10
#url dati incidenti
urldati_incidenti="https://esploradati.istat.it/SDMXWS/rest/v2/structure/dataflow/IT1/41_983/1.0"

#NB aggiungo nella richiesta di ottenere il body della risposta in formato csv
headers_json={'Accept': 'application/vnd.sdmx.structure+json;version=2.0.0'}
#eseguo la richiesta con Verbo Http GET e con l'aggiunta dell'header nella sezione della richiesta 
rq_incidente_struttura = api.get(urldati_incidenti, headers=headers_json)

# %%
print(rq_incidente_struttura.content)
# Out:
# b'{"meta":{"id":"IREF178301","test":false,"schema":"https://raw.githubusercontent.com/sdmx-twg/sdmx-json/develop/structure-message/tools/schemas/2.0.0/sdmx-json-structure-schema.json","prepared":"2026-05-09T11:10:31Z","contentLanguages":["en"],"sender":{"id":"FusionRegistry"}},"data":{"dataflows":[{"links":[{"rel":"self","type":"dataflow","uri":"https://raw.githubusercontent.com/sdmx-twg/sdmx-json/develop/structure-message/tools/schemas/2.0.0/sdmx-json-structure-schema.json","urn":"urn:sdmx:org.sdmx.infomodel.datastructure.Dataflow=IT1:41_983(1.0)"}],"id":"41_983","annotations":[{"id":"DDBDataflow","title":"851859858F7F55E81C027BB3764D67E3","type":"DDBDataflow"},{"id":"METADATA_URL","title":"METADATA_URL","type":"METADATA_URL"},{"id":"LAST_UPDATE","title":"2025-10-14T09:09:11.091Z","type":"LAST_UPDATE"}],"name":"Road accidents, killed and injured - municipalities","names":{"en":"Road accidents, killed and injured - municipalities","it":"Incidenti, morti e feriti - comuni"},"version":
# ...
