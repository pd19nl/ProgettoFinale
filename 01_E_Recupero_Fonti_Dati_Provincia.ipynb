# %% [markdown]
# #Sorgente dati:
# https://situas.istat.it/web/#/apiDetail
#
# Dettaglio API
#
# Dettaglio API
#
# Id report:
# 64
# Titolo report:
# Elenco Province/Uts
# Inizio/fine validità report:
# 01/01/1948 - 12/05/2026
# Analisi temporale:
# DATA
# Ambito territoriale:
# Unità amministrative
# Unità territoriale:
# Provincia/Uts
# Parametri necessari:
# pfun - pdata
# pfun: Id report
# pdata: data di estrazione (formato GG/MM/AAAA)
# Dati:
# https://situas-servizi.istat.it/publish/reportspooljson?pfun=64&pdata=01/01/1948
# Conteggio:
# https://situas-servizi.istat.it/publish/reportspooljsoncount?pfun=64&pdata=01/01/1948
# Metadati:
# https://situas-servizi.istat.it/publish/anagrafica_report_metadato_web?pfun=64&pdata=01/01/1948
#
#
# metadati del documento:
#
# {
#     "REPORT NAME": "Elenco Province/Uts",
#     "REPORT DESCRIZIONE": "Il report restituisce la lista delle province o unità territoriali sovracomunali (Uts) vigenti alla data selezionata e le loro principali caratteristiche o classificazioni statistico-amministrative disponibili. Ogni unità territoriale è identificata dalla denominazione e dal codice statistico.",
#     "COL_DETAILS": [
#         {
#             "COLNAME": "COD_RIP",
#             "LABEL": "Codice Ripartizione geografica",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Codice Istat della ripartizione geografica secondo la suddivisione del territorio nazionale in: 1) Nord-ovest, 2) Nord-est, 3) Centro, 4) Sud e 5) Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "COD_REG",
#             "LABEL": "Codice Regione",
#             "NOTE": "Valore  di due caratteri alfanumerici, con validità nell'intervallo  01- 20.",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Regione",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_PROV_STORICO",
#             "LABEL": "Codice Provincia (storico)",
#             "NOTE": "A partire dal 1/1/2015 con l'entrata in vigore delle Città metropolitane i codici delle Province corrispondenti permangono al solo scopo di costituire il codice del comune, che non subisce variazioni. Allo stesso scopo, e ai soli fini statistici, permangono i codici delle soppresse Province del Friuli-Venezia Giulia (l.r. 20/2016)",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Provincia vigente o cessata (tre caratteri, formato alfanumerico con validità nell’intervallo 001-119)",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_UTS",
#             "LABEL": "Codice Provincia/Uts",
#             "NOTE": "Codice di tre caratteri alfanumerici con validità nell’intervallo 001-119 per le Province. Restano assegnati ai Liberi consorzi i codici delle omonime ex Province (validi nell'intervallo 081-089). Il codice delle Città metropolitane è, invece, creato sommando '200' al codice della provincia corrispondente. Ai soli fini statistici, permangono i codici delle soppresse Province del Friuli-Venezia Giulia, cessate secondo le modalità espresse con Legge regionale 20/2016.",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Provincia o Unità territoriale sovracomunale (Uts). Le Unità territoriali sovracomunali, definite a fini statistici, ricomprendono, a partire dal 2015, oltre le Province anche le Città metropolitane, i Liberi consorzi e le unità non amministrative (ex Province del Friuli-Venezia Giulia).",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DEN_UTS",
#             "LABEL": "Provincia/Uts",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Denominazione della Provincia o Unità territoriale sovracomunale (Uts).",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DEN_RIP",
#             "LABEL": "Ripartizione geografica",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Denominazione della ripartizione geografica  secondo la suddivisione del territorio nazionale in 5 ambiti: Nord-ovest, Nord-est, Centro, Sud e Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DEN_REG",
#             "LABEL": "Regione",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Denominazione della Regione",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "TIPO_UTS",
#             "LABEL": "Tipologia Provincia/Uts",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Tipologia dell'Unità territoriale sovracomunale (Uts): 1=Provincia; 2=Provincia autonoma; 3=Città metropolitana; 4=Libero consorzio di comuni; 5=Unità non amministrativa (ex- province del Friuli-Venezia Giulia)",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "DESC_TIPO_UTS",
#             "LABEL": "Descrizione tipologia Provincia/Uts",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Descrizione della tipologia di Unità territoriale sovracomunale (Uts): Provincia; Provincia autonoma; Città metropolitana; Libero consorzio di comuni; Unità non amministrativa (ex- province del Friuli-Venezia Giulia)",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "SIGLA_AUTOMOBILISTICA",
#             "LABEL": "Sigla automobilistica",
#             "NOTE": "",
#             "LINK": "",
#             "GUIDA": "Sigla automobilistica della Provincia, e dal 2015 della Città metropolitana, libero consorzio o unità non amministrativa (ex Province del Friuli-Venezia Giulia). Null quando non disponibile",
#             "FORMATMASK": "",
#             "FONTE": "Motorizzazione",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_PROV_FISCALE",
#             "LABEL": "Codice fiscale",
#             "NOTE": "Codice di 11 caratteri in formato testo",
#             "LINK": "",
#             "GUIDA": "Codice attribuito dall’Agenzia delle Entrate al fine di identificare in modo univoco un soggetto giuridico",
#             "FORMATMASK": "",
#             "FONTE": "Agenzia delle entrate",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_NUTS3_2024",
#             "LABEL": "Codice NUTS3 2024",
#             "NOTE": "Cfr. Commission Delegated Regulation 2023/674",
#             "LINK": "https://ec.europa.eu/eurostat/web/nuts/history",
#             "GUIDA": "Nomenclatura delle unità territoriali europee (NUTS3) corrispondente al livello territoriale delle Province/Citta metropolitane (Uts-Unità territoriali sovracomunali), valida dal 2024 con il cambio denominazione della Nuts3 Reggio di Calabria in Reggio Calabria, fino al 2026. La Nomenclatura Nuts3 versione 2024 non include la classificazione delle Province sarde \"Gallura Nord-Est Sardegna, \"Ogliastra\", \"Sulcis Iglesiente\" e \"Medio Campidano\" e la Città metropolitana di Sassari, istituite nel 2025.",
#             "FORMATMASK": "",
#             "FONTE": "Eurostat",
#             "TYPE": "VARCHAR"
#         }
#     ]
# }

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali creati per questa fase

#aggiunto quando ho spostato i file in una cartella a parte
import sys
sys.path.append("./Moduli")

import Modulo_Fase_01 as fase1
#pip install reloading
#from reloading import reloading

# %%
fase1.RecuperaESalvaDatiIstat("64","Dati_Province","Province")
# Out:
# Avvio esportazione dati Province per anno
# Elaborazione dati regione anno 2015
#    Recupero  dati anno 2015
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2015
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2015.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2015.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2015.csv
# Elaborazione dati regione anno 2016
#    Recupero  dati anno 2016
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2016
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2016.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2016.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2016.csv
# Elaborazione dati regione anno 2017
#    Recupero  dati anno 2017
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2017
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2017.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2017.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2017.csv
# Elaborazione dati regione anno 2018
#    Recupero  dati anno 2018
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2018
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2018.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2018.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2018.csv
# Elaborazione dati regione anno 2019
#    Recupero  dati anno 2019
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2019
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2019.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2019.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2019.csv
# Elaborazione dati regione anno 2020
#    Recupero  dati anno 2020
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2020
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2020.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2020.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2020.csv
# Elaborazione dati regione anno 2021
#    Recupero  dati anno 2021
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2021
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2021.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2021.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2021.csv
# Elaborazione dati regione anno 2022
#    Recupero  dati anno 2022
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2022
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2022.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2022.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2022.csv
# Elaborazione dati regione anno 2023
#    Recupero  dati anno 2023
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2023
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2023.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2023.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2023.csv
# Elaborazione dati regione anno 2024
#    Recupero  dati anno 2024
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2024
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2024.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2024.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2024.csv
# Elaborazione dati regione anno 2025
#    Recupero  dati anno 2025
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2025
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2025.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2025.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2025.csv
# Elaborazione dati regione anno 2026
#    Recupero  dati anno 2026
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Province_2026
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2026.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2026.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_2026.csv
# Fine esportazione dati {ambito} per anno

# %%
fase1.UnioneFileCsvPerAnno("Dati_Province")
# Out:
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2016.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2017.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2018.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2019.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2020.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2021.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2022.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2023.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2024.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2025.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Province_2026.csv
# file: Dati_Province_All
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_All.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_All.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Province_All.csv
