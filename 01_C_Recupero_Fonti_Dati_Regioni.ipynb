# %% [markdown]
# #Sorgente dati:
# https://situas.istat.it/web/#/apiDetail
#
# Dettaglio API
#
# Id report:
# 68
# Titolo report:
# Elenco Regioni
# Inizio/fine validità report:
# 01/01/1948 - 09/05/2026
# Analisi temporale:
# DATA
# Ambito territoriale:
# Unità amministrative
# Unità territoriale:
# Regione
# Parametri necessari:
# pfun - pdata
# pfun: Id report
# pdata: data di estrazione (formato GG/MM/AAAA)
# Dati:
# https://situas-servizi.istat.it/publish/reportspooljson?pfun=68&pdata=01/01/1948
# Conteggio:
# https://situas-servizi.istat.it/publish/reportspooljsoncount?pfun=68&pdata=01/01/1948
# Metadati:
# https://situas-servizi.istat.it/publish/anagrafica_report_metadato_web?pfun=68&pdata=01/01/1948
#
#
# metadati del documento:
#
# {
#     "REPORT NAME": "Elenco Regioni",
#     "REPORT DESCRIZIONE": "Il report restituisce la lista delle regioni vigenti alla data selezionata e le loro principali caratteristiche o classificazioni statistico-amministrative disponibili.",
#     "COL_DETAILS": [
#         {
#             "COLNAME": "COD_RIP",
#             "LABEL": "Codice Ripartizione geografica",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Codice Istat della ripartizione geografica secondo la suddivisione del territorio nazionale in: 1) Nord-ovest, 2) Nord-est, 3) Centro, 4) Sud e 5) Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#         {
#             "COLNAME": "COD_REG",
#             "LABEL": "Codice Regione",
#             "NOTE": "Valore  di due caratteri alfanumerici, con validità nell'intervallo  01- 20.",
#             "LINK": "",
#             "GUIDA": "Codice Istat della regione",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DEN_REG",
#             "LABEL": "Regione",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Denominazione della regione",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DEN_RIP",
#             "LABEL": "Ripartizione geografica",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Denominazione della ripartizione geografica  secondo la suddivisione del territorio nazionale in 5 ambiti: Nord-ovest, Nord-est, Centro, Sud e Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "TIPO_REG",
#             "LABEL": "Flag tipo regione",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Descrizione Ente: 1= Regione a Statuto ordinario; 2=Regione a Statuto speciale",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "DESC_TIPO_REG",
#             "LABEL": "Tipo regione",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Regione a statuto ordinario o Regione a statuto speciale",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_REG_FISCALE",
#             "LABEL": "Codice fiscale",
#             "NOTE": "Codice di 11 caratteri in formato testo",
#             "LINK": "",
#             "GUIDA": "Codice attribuito dall’Agenzia delle Entrate al fine di identificare in modo univoco un soggetto giuridico",
#             "FORMATMASK": "",
#             "FONTE": "Agenzia delle Entrate",
#             "TYPE": "VARCHAR"
#         },
#         {
#             "COLNAME": "COD_NUTS2_2010",
#             "LABEL": "Codice NUTS2 2010",
#             "NOTE": "Cfr. Regolamenti (UE) della Commissione n. 31/2011, n. 1319/2013 e n. 2066/2016. Nella nomenclatura NUTS non è presente la regione di livello 2 \"Trentino-Alto Adige/Südtirol\", al suo posto compaiono la \"Provincia autonoma di Bolzano/Bozen\" (ITH1) e la \"Provincia autonoma di Trento\" (ITH2).",
#             "LINK": "https://ec.europa.eu/eurostat/web/nuts/history",
#             "GUIDA": "Nomenclatura delle unità territoriali europee (NUTS2) corrispondente al livello territoriale delle regioni, valida dal 2010 al 2020",
#             "FORMATMASK": "",
#             "FONTE": "Eurostat",
#             "TYPE": "VARCHAR"
#         }
#     ]
# }

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali creati per questa fase

#aggiunto quando ho spostato i file in una cartella a parte
import sys
sys.path.append("./Moduli")

import Modulo_Fase_01 as fase1
#pip install reloading
#from reloading import reloading

# %%
fase1.RecuperaESalvaDatiIstat("68","Dati_Regione","Regione")
# Out:
# Avvio esportazione dati Regione per anno
# Elaborazione dati regione anno 2015
#    Recupero  dati anno 2015
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2015
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2015.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2015.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2015.csv
# Elaborazione dati regione anno 2016
#    Recupero  dati anno 2016
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2016
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2016.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2016.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2016.csv
# Elaborazione dati regione anno 2017
#    Recupero  dati anno 2017
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2017
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2017.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2017.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2017.csv
# Elaborazione dati regione anno 2018
#    Recupero  dati anno 2018
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2018
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2018.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2018.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2018.csv
# Elaborazione dati regione anno 2019
#    Recupero  dati anno 2019
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2019
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2019.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2019.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2019.csv
# Elaborazione dati regione anno 2020
#    Recupero  dati anno 2020
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2020
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2020.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2020.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2020.csv
# Elaborazione dati regione anno 2021
#    Recupero  dati anno 2021
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2021
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2021.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2021.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2021.csv
# Elaborazione dati regione anno 2022
#    Recupero  dati anno 2022
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2022
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2022.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2022.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2022.csv
# Elaborazione dati regione anno 2023
#    Recupero  dati anno 2023
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2023
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2023.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2023.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2023.csv
# Elaborazione dati regione anno 2024
#    Recupero  dati anno 2024
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2024
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2024.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2024.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2024.csv
# Elaborazione dati regione anno 2025
#    Recupero  dati anno 2025
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2025
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2025.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2025.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2025.csv
# Elaborazione dati regione anno 2026
#    Recupero  dati anno 2026
#       status_code_risposta : 200
#       Converto i dati json ricevuti in DataFrame
#       Salvo i dati in CSV su FS. Nome file=Dati_Regione_2026
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2026.csv
#       Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2026.csv' non esiste
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_2026.csv
# Fine esportazione dati {ambito} per anno

# %%
fase1.UnioneFileCsvPerAnno("Dati_Regione")
# Out:
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2016.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2017.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2018.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2019.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2020.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2021.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2022.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2023.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2024.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2025.csv
# Concateno: c:\progetto_dataanalyst\progettofinale\Data\Dati_Regione_2026.csv
# file: Dati_Regione_All
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_All.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_All.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Data/Dati_Regione_All.csv
