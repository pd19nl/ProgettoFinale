# %% [markdown]
# # metadati
#
# la descrizione dei campi è stata presa dal formato xml in cui era presente lo schema
# DATAFLOW,
# FREQ,
# REF_AREA,
# DATA_TYPE,
# RESULT,
# TIME_PERIOD,        --> anno di riferimento (dal 2001)
#                         si mantiene
# OBS_VALUE,
# OBS_STATUS,
# NOTE_DS,
# NOTE_REF_AREA,
# NOTE_DATA_TYPE,
# NOTE_RESULT,
# NOTE_TIME_PERIOD,
# BASE_PER,
# UNIT_MEAS,
# UNIT_MULT

# %%
# =============================================================
# =============================================================
#
# librerie di base
import numpy as np
import pandas as pd

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali creati per questa fase


#aggiunto quando ho spostato i file in una cartella a parte
import sys
sys.path.append("./Moduli")

#import Moduli.Modulo_Fase_02 as pd_fase1

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali per uso comune
import Moduli.Modulo_Common as pd_common

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali per uso comune
import Moduli.Modulo_Configurazione as pd_config

# %%
df_incidenti = pd.read_csv( pd_common.GetFolderDati()+ "//Dati_Incidenti.csv")

# %%
#non carica gli anni 2025 e 2026 presenti nel file

# %%
df_incidenti.TIME_PERIOD.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
df_incidenti[df_incidenti['TIME_PERIOD'] == 2024]
# Out:
#         Unnamed: 0         DATAFLOW FREQ  REF_AREA DATA_TYPE RESULT  \
# 23              23  IT1:41_983(1.0)    A      1001   KILLINJ      F
# 47              47  IT1:41_983(1.0)    A      1001   KILLINJ      M
# 71              71  IT1:41_983(1.0)    A      1001   ROADACC      9
# 95              95  IT1:41_983(1.0)    A      1002   KILLINJ      F
# 119            119  IT1:41_983(1.0)    A      1002   KILLINJ      M
# ...            ...              ...  ...       ...       ...    ...
# 573519      573519  IT1:41_983(1.0)    A    111106   KILLINJ      M
# 573527      573527  IT1:41_983(1.0)    A    111106   ROADACC      9
# 573535      573535  IT1:41_983(1.0)    A    111107   KILLINJ      F
# 573543      573543  IT1:41_983(1.0)    A    111107   KILLINJ      M
# 573551      573551  IT1:41_983(1.0)    A    111107   ROADACC      9
#
#         TIME_PERIOD  OBS_VALUE  OBS_STATUS  NOTE_DS  NOTE_REF_AREA  \
# 23             2024          5         NaN      NaN            NaN
# ...

# %%
df_incidenti.head(5)
# Out:
#    Unnamed: 0         DATAFLOW FREQ  REF_AREA DATA_TYPE RESULT  TIME_PERIOD  \
# 0           0  IT1:41_983(1.0)    A      1001   KILLINJ      F         2001
# 1           1  IT1:41_983(1.0)    A      1001   KILLINJ      F         2002
# 2           2  IT1:41_983(1.0)    A      1001   KILLINJ      F         2003
# 3           3  IT1:41_983(1.0)    A      1001   KILLINJ      F         2004
# 4           4  IT1:41_983(1.0)    A      1001   KILLINJ      F         2005
#
#    OBS_VALUE  OBS_STATUS  NOTE_DS  NOTE_REF_AREA  NOTE_DATA_TYPE  NOTE_RESULT  \
# 0         10         NaN      NaN            NaN             NaN          NaN
# 1         10         NaN      NaN            NaN             NaN          NaN
# 2          7         NaN      NaN            NaN             NaN          NaN
# 3         13         NaN      NaN            NaN             NaN          NaN
# 4          2         NaN      NaN            NaN             NaN          NaN
#
# ...

# %%
df_incidenti_analisi= df_incidenti.copy()

# %%
df_incidenti_analisi.FREQ.unique()
# Out:
# array(['A'], dtype=object)

# %%
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573552 entries, 0 to 573551
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        573552 non-null  int64
#  1   DATAFLOW          573552 non-null  object
#  2   FREQ              573552 non-null  object
#  3   REF_AREA          573552 non-null  int64
#  4   DATA_TYPE         573552 non-null  object
#  5   RESULT            573552 non-null  object
#  6   TIME_PERIOD       573552 non-null  int64
#  7   OBS_VALUE         573552 non-null  int64
#  8   OBS_STATUS        0 non-null       float64
#  9   NOTE_DS           0 non-null       float64
#  10  NOTE_REF_AREA     0 non-null       float64
#  11  NOTE_DATA_TYPE    0 non-null       float64
#  12  NOTE_RESULT       0 non-null       float64
#  13  NOTE_TIME_PERIOD  0 non-null       float64
#  14  BASE_PER          0 non-null       float64
# ...

# %%
#rimozione campi vuoti 
df_incidenti_analisi = df_incidenti_analisi.drop('OBS_STATUS',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('NOTE_DS',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('NOTE_REF_AREA',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('NOTE_DATA_TYPE',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('NOTE_RESULT',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('NOTE_TIME_PERIOD',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('BASE_PER',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('UNIT_MEAS',axis=1)
df_incidenti_analisi = df_incidenti_analisi.drop('UNIT_MULT',axis=1)

# %%
df_incidenti_analisi.FREQ.unique()
# Out:
# array(['A'], dtype=object)

# %%
#rimozione campi costanti
df_incidenti_analisi = df_incidenti_analisi.drop('FREQ',axis=1)

# %%
df_incidenti_analisi.DATAFLOW.unique()
# Out:
# array(['IT1:41_983(1.0)'], dtype=object)

# %%
#rimozione campi costanti
df_incidenti_analisi = df_incidenti_analisi.drop('DATAFLOW',axis=1)

# %%
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573552 entries, 0 to 573551
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   573552 non-null  int64
#  1   REF_AREA     573552 non-null  int64
#  2   DATA_TYPE    573552 non-null  object
#  3   RESULT       573552 non-null  object
#  4   TIME_PERIOD  573552 non-null  int64
#  5   OBS_VALUE    573552 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ MB

# %%
df_incidenti_analisi.head(2)
# Out:
#    Unnamed: 0  REF_AREA DATA_TYPE RESULT  TIME_PERIOD  OBS_VALUE
# 0           0      1001   KILLINJ      F         2001         10
# 1           1      1001   KILLINJ      F         2002         10

# %%
df_incidenti_analisi.RESULT.unique()
# Out:
# array(['F', 'M', '9'], dtype=object)

# %%
#IL DATO TIPO 9 SONO I TOTALI, li rimuovo dal datase
df_incidenti_analisi = df_incidenti_analisi[df_incidenti_analisi['RESULT']!='9']

# %%
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382368 entries, 0 to 573543
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   382368 non-null  int64
#  1   REF_AREA     382368 non-null  int64
#  2   DATA_TYPE    382368 non-null  object
#  3   RESULT       382368 non-null  object
#  4   TIME_PERIOD  382368 non-null  int64
#  5   OBS_VALUE    382368 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 20.4+ MB

# %%
df_incidenti_analisi.DATA_TYPE.unique()
# Out:
# array(['KILLINJ'], dtype=object)

# %%
#rimozione campi costanti
df_incidenti_analisi = df_incidenti_analisi.drop('DATA_TYPE',axis=1)

# %%
df_incidenti_analisi.TIME_PERIOD.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
df_incidenti_analisi.count()
# Out:
# Unnamed: 0     382368
# REF_AREA       382368
# RESULT         382368
# TIME_PERIOD    382368
# OBS_VALUE      382368
# dtype: int64

# %%
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382368 entries, 0 to 573543
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   382368 non-null  int64
#  1   REF_AREA     382368 non-null  int64
#  2   RESULT       382368 non-null  object
#  3   TIME_PERIOD  382368 non-null  int64
#  4   OBS_VALUE    382368 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 17.5+ MB

# %%
#tipo dati corretto CON LA VERSIONE PYTHON ULTIMA, MENTRE CON QUELLA ANACONDA (VERSIONE PREDENTE CAMBIATO IL FORMATO STR IN OBJECT)
#non faccio nulla --> CAMBIO DOPO

# %%
df_incidenti_analisi['RESULT_DESC']='Feriti'

# %%
df_incidenti_analisi.loc[df_incidenti_analisi['RESULT'] == 'M', ['RESULT_DESC']] = 'Morti'

# %%
df_incidenti_analisi.RESULT.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df_incidenti_analisi.RESULT_DESC.unique()
# Out:
# array(['Feriti', 'Morti'], dtype=object)

# %%
df_incidenti_analisi.groupby(['RESULT','RESULT_DESC'])['OBS_VALUE'].agg('count')
# Out:
# RESULT  RESULT_DESC
# F       Feriti         191184
# M       Morti          191184
# Name: OBS_VALUE, dtype: int64

# %%
#verifico
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382368 entries, 0 to 573543
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   382368 non-null  int64
#  1   REF_AREA     382368 non-null  int64
#  2   RESULT       382368 non-null  object
#  3   TIME_PERIOD  382368 non-null  int64
#  4   OBS_VALUE    382368 non-null  int64
#  5   RESULT_DESC  382368 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 20.4+ MB

# %%
#df_incidenti_analisi["RESULT"] = df_incidenti_analisi["RESULT"].astype('str')
df_incidenti_analisi["RESULT"] = df_incidenti_analisi["RESULT"].astype('string')

# %%
df_incidenti_analisi["RESULT_DESC"] = df_incidenti_analisi["RESULT_DESC"].astype('string')

# %%
#verifico
df_incidenti_analisi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 382368 entries, 0 to 573543
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Unnamed: 0   382368 non-null  int64
#  1   REF_AREA     382368 non-null  int64
#  2   RESULT       382368 non-null  string
#  3   TIME_PERIOD  382368 non-null  int64
#  4   OBS_VALUE    382368 non-null  int64
#  5   RESULT_DESC  382368 non-null  string
# dtypes: int64(4), string(2)
# memory usage: 20.4 MB

# %%
#lettura dati relativi al OBS_VALUE
df_incidenti_analisi.OBS_VALUE.describe()
# Out:
# count    382368.000000
# mean         17.812605
# std         239.711176
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           5.000000
# max       30254.000000
# Name: OBS_VALUE, dtype: float64

# %%
df_incidenti_analisi[df_incidenti_analisi.OBS_VALUE== 30254]
# Out:
#         Unnamed: 0  REF_AREA RESULT  TIME_PERIOD  OBS_VALUE RESULT_DESC
# 348588      348588     58091      F         2004      30254      Feriti

# %%
#rimuovo i casi non significativi
print(f'tot rec: {df_incidenti_analisi.REF_AREA.count()}') #382368
rec_mag_0 = df_incidenti_analisi[df_incidenti_analisi.OBS_VALUE> 0].REF_AREA.count()
rec_equ_0 = df_incidenti_analisi[df_incidenti_analisi.OBS_VALUE== 0].REF_AREA.count()
print(f'rec >0: {rec_mag_0}')
print(f'rec =0: {rec_equ_0}')
print(f'tot derivato: {rec_equ_0+rec_mag_0}')
# Out:
# tot rec: 382368
# rec >0: 194998
# rec =0: 187370
# tot derivato: 382368

# %%
df_incidenti_analisi.TIME_PERIOD.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
df_incidenti_analisi=df_incidenti_analisi[df_incidenti_analisi.OBS_VALUE> 0]

# %%
df_incidenti_analisi.TIME_PERIOD.unique()
# Out:
# array([2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2018, 2019, 2020, 2021, 2022, 2023,
#        2024, 2017])

# %%
#lettura dati relativi al OBS_VALUE
df_incidenti_analisi.OBS_VALUE.describe()
# Out:
# count    194998.000000
# mean         34.928410
# std         334.779855
# min           1.000000
# 25%           2.000000
# 50%           5.000000
# 75%          18.000000
# max       30254.000000
# Name: OBS_VALUE, dtype: float64

# %%
pd_config.GetAnnoInizioAnalisi()
# Out:
# 2010

# %%
df_incidenti_analisi = df_incidenti_analisi[df_incidenti_analisi.TIME_PERIOD  >= pd_config.GetAnnoInizioAnalisi()]

# %%
df_incidenti_analisi.TIME_PERIOD.unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2018, 2019, 2020, 2021,
#        2022, 2023, 2024, 2017])

# %%
df_incidenti_analisi.head(5)
# Out:
#     Unnamed: 0  REF_AREA RESULT  TIME_PERIOD  OBS_VALUE RESULT_DESC
# 9            9      1001      F         2010         14      Feriti
# 10          10      1001      F         2011          6      Feriti
# 11          11      1001      F         2012          8      Feriti
# 12          12      1001      F         2013          5      Feriti
# 13          13      1001      F         2014         11      Feriti

# %%
#SALVO IL DATASET FINALE

pd_common.SalvaDataset(df_incidenti_analisi, f"ElencoIncidenti",False)
# Out:
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Analisi/ElencoIncidenti.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Analisi/ElencoIncidenti.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Analisi/ElencoIncidenti.csv

# %%
dftipoevento = df_incidenti_analisi.groupby(['RESULT','RESULT_DESC'], as_index=False).size()
#['OBS_VALUE'].agg('count')

# %%
dftipoevento.head()
# Out:
#   RESULT RESULT_DESC   size
# 0      F      Feriti  92836
# 1      M       Morti  25337

# %%
dftipoevento =dftipoevento[['RESULT','RESULT_DESC']]

# %%
dftipoevento
# Out:
#   RESULT RESULT_DESC
# 0      F      Feriti
# 1      M       Morti

# %%
dftipoevento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RESULT       2 non-null      string
#  1   RESULT_DESC  2 non-null      string
# dtypes: string(2)
# memory usage: 164.0 bytes

# %%
pd_common.SalvaDataset(dftipoevento, f"TipoEvento",False)
# Out:
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Analisi/TipoEvento.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Analisi/TipoEvento.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Analisi/TipoEvento.csv
