# %% [markdown]
# # metadati
# preso dal link indicato in file 01_b
#
#
#        {
#     "REPORT NAME": "Comuni - Dimensione",
#     "REPORT DESCRIZIONE": "Il report restituisce la lista dei comuni esistenti alla data selezionata e la relativa dimensione in termini di ampiezza demografica (popolazione residente e legale) e di estensione territoriale (superficie in kmq). Ogni unità è identificata dalla denominazione e dal codice statistico. Il dato sulla popolazione legale viene reso disponibile a partire dal IX Censimento generale della popolazione (4 novembre 1951), quello sulla popolazione residente dal 31 dicembre 2001 mentre la superficie territoriale a partire dal XIV Censimento generale della popolazione e delle abitazioni (21 ottobre 2001).",
#     "COL_DETAILS": [
#
# si ma sarà presa dalla regione
#         {
#             "COLNAME": "COD_RIP",
#             "LABEL": "Codice Ripartizione geografica",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Ripartizione geografica secondo la suddivisione del territorio nazionale in: 1) Nord-ovest, 2) Nord-est, 3) Centro, 4) Sud e 5) Isole.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#
# si
#         {
#             "COLNAME": "COD_REG",
#             "LABEL": "Codice Regione",
#             "NOTE": "Valore  di due caratteri alfanumerici, con validità nell'intervallo  01- 20.",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Regione.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
#
# no
#         {
#             "COLNAME": "COD_PROV_STORICO",
#             "LABEL": "Codice Provincia (Storico)",
#             "NOTE": "A partire dal 1/1/2015 con l'entrata in vigore delle Città metropolitane i codici delle Province corrispondenti permangono al solo scopo di costituire il codice del Comune, che non subisce variazioni. Allo stesso scopo, e ai soli fini statistici, permangono i codici delle soppresse Province del Friuli-Venezia Giulia (l.r. 20/2016)",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Provincia vigente o cessata (tre caratteri, formato alfanumerico con validità nell’intervallo 001-119)",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# si incerto
#         {
#             "COLNAME": "COD_UTS",
#             "LABEL": "Codice Provincia/Uts",
#             "NOTE": "Codice di tre caratteri alfanumerici con validità nell’intervallo 001-119 per le Province. Restano assegnati ai Liberi consorzi i codici delle omonime ex Province (validi nell'intervallo 081-089). Il codice delle Città metropolitane è, invece, creato sommando '200' al codice della Provincia corrispondente. Ai soli fini statistici, permangono i codici delle soppresse Province del Friuli-Venezia Giulia, cessate secondo le modalità espresse con Legge regionale 20/2016.",
#             "LINK": "",
#             "GUIDA": "Codice Istat della Provincia o Unità territoriale sovracomunale (Uts). Le unità territoriali sovracomunali, definite a fini statistici, ricomprendono, a partire dal 2015, oltre le Province anche le Città metropolitane, i Liberi consorzi e le unità non amministrative (ex Province del Friuli-Venezia Giulia).",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# no
#         {
#             "COLNAME": "PRO_COM_T",
#             "LABEL": "Codice Comune (alfanumerico)",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Codice Istat del Comune di sei caratteri in formato alfanumerico",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# si
#         {
#             "COLNAME": "PRO_COM",
#             "LABEL": "Codice Comune (numerico)",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Codice Istat del Comune di sei caratteri in formato numerico",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#
# si
#         {
#             "COLNAME": "COMUNE",
#             "LABEL": "Comune",
#             "NOTE": "La denominazione ufficiale dei comuni della Provincia di Bolzano/Bozen e di alcuni comuni dell Friuli-Venezia Giulia è definita dall'associazione del nome italiano a quello straniero. Per le denominazioni bilingue è previsto l'uso del simbolo separatore: \"/\" per i comuni della Provincia di Bolzano/Bozen, e \"-\" per tutti gli altri.",
#             "LINK": "",
#             "GUIDA": "Denominazione del Comune in lingua italiana e straniera",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# no
#         {
#             "COLNAME": "COMUNE_A",
#             "LABEL": "Comune (dizione straniera)",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Denominazione del Comune in lingua diversa dall'italiano",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# no
#         {
#             "COLNAME": "SIGLA_AUTOMOBILISTICA",
#             "LABEL": "Sigla automobilistica",
#             "NOTE": "Note non presenti",
#             "LINK": " ",
#             "GUIDA": "Sigla automobilistica della Provincia, e dal 2015 della Città metropolitana, Libero consorzio o unità non amministrativa.",
#             "FORMATMASK": "",
#             "FONTE": "Motorizzazione",
#             "TYPE": "VARCHAR"
#         },
#
# no prendo pop_res
#         {
#             "COLNAME": "POP_LEG",
#             "LABEL": "Popolazione legale",
#             "NOTE": "Per i comuni istituiti o interessati rispettivamente da processi di fusione o incorporazione di comuni soppressi, la popolazione alla data del  Censimento generale della popolazione è ricostruita per somma. Per i comuni interessati da eventi di cessioni e/o acquisizioni di porzioni di territorio la popolazione legale è ricostruita secondo i dati trasmessi dai Comuni interessati.",
#             "LINK": " ",
#             "GUIDA": "Popolazione residente legale alla data del Censimento di riferimento determinata con Decreto del Presidente della Repubblica.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#
# no
#
#         {
#             "COLNAME": "ANNO_CENSIMENTO",
#             "LABEL": "Anno Censimento",
#             "NOTE": "Note non presenti",
#             "LINK": " ",
#             "GUIDA": "Anno di riferimento dei dati",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# si
#         {
#             "COLNAME": "AREA_KMQ",
#             "LABEL": "Superficie (Kmq)",
#             "NOTE": "I dati, rilasciati ai soli fini statistici, sono diffusi annualmente, a partire dal 2002 con riferimenti al 1° gennaio.\r\nFanno eccezione gli anni censuari 2001 e 2011, riferiti rispettivamente al 21 ottobre e al 9 ottobre, e l'anno 2021, riferito al 31 dicembre.\"\r\nSuccessivamente a tali date, in caso di eventi di fusione o incorporazione, la superficie è ricostruita per somma. Resta invece invariata la superficie dei Comuni interessati da cessioni o acquisizioni di singole porzioni di territorio",
#             "LINK": "https://www.istat.it/notizia/confini-delle-unita-amministrative-a-fini-statistici-al-1-gennaio-2018-2/",
#             "GUIDA": "Superficie comunale espressa in kmq ricavata dallo strato geografico dei limiti comunali tramite il sistema informativo geografico (GIS) in uso presso l’Istat. Il dato può subire variazioni annuali dovute agli arrotondamenti nel calcolo o all'aggiornamento della base censuaria di riferimento.",
#             "FORMATMASK": "",
#             "FONTE": "Istat-Basi territoriali, Confini delle unità amministrative a fini statistici (shapefile - versione non generalizzata)",
#             "TYPE": "VARCHAR"
#         },
#
# no
#         {
#             "COLNAME": "ANNO_AREA",
#             "LABEL": "Anno (Superficie)",
#             "NOTE": "Note non presenti",
#             "LINK": "",
#             "GUIDA": "Anno di riferimento dei dati",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         },
#
# si
#         {
#             "COLNAME": "POP_RES",
#             "LABEL": "Popolazione residente",
#             "NOTE": "Successivamente al 31 dicembre dell'anno di riferimento, per i Comuni istituiti mediante fusione o in caso di incorporazione di comuni soppressi, la popolazione è ricostruita per somma. Resta invariata la popolazione dei Comuni con eventi di cessioni e/o acquisizioni di porzioni di territorio.",
#             "LINK": "https://demo.istat.it/",
#             "GUIDA": "Elaborazione della popolazione residente al 31 dicembre dell'anno di riferimento. Movimento e calcolo della popolazione residente annuale.",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "NUMBER"
#         },
#
# no
#         {
#             "COLNAME": "ANNO_POP_RES",
#             "LABEL": "Anno (Popolazione residente)",
#             "NOTE": "Note non presenti",
#             "LINK": " ",
#             "GUIDA": "Anno di riferimento dei dati",
#             "FORMATMASK": "",
#             "FONTE": "Istat",
#             "TYPE": "VARCHAR"
#         }
#     ]
# }

# %%
# =============================================================
# =============================================================
#
# librerie di base
import numpy as np
import pandas as pd

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali creati per questa fase


#aggiunto quando ho spostato i file in una cartella a parte
import sys
sys.path.append("./Moduli")

#import Moduli.Modulo_Fase_02 as pd_fase1

# %%
# =============================================================
# =============================================================
#
# importo le funzioni personali per uso comune
import Moduli.Modulo_Common as pd_common

# %%
df_comuni = pd.read_csv( pd_common.GetFolderDati()+ "//Dati_Comune_All.csv")

# %%
df_comuni.head(5)
# Out:
#    Unnamed: 0.1  Unnamed: 0  COD_RIP  COD_REG  COD_PROV_STORICO  COD_UTS  \
# 0             0           0        1        1                 1      201
# 1             1           1        1        1                 1      201
# 2             2           2        1        1                 1      201
# 3             3           3        1        1                 1      201
# 4             4           4        1        1                 1      201
#
#    PRO_COM_T  PRO_COM           COMUNE COMUNE_A SIGLA_AUTOMOBILISTICA  \
# 0       1001     1001            Agliè      NaN                    TO
# 1       1002     1002          Airasca      NaN                    TO
# 2       1003     1003     Ala di Stura      NaN                    TO
# 3       1004     1004  Albiano d'Ivrea      NaN                    TO
# 4       1005     1005  Alice Superiore      NaN                    TO
#
#    POP_LEG  ANNO_CENSIMENTO AREA_KMQ  ANNO_AREA  POP_RES  ANNO_POP_RES  \
# ...

# %%
df_comuni.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'COD_RIP', 'COD_REG', 'COD_PROV_STORICO',
#        'COD_UTS', 'PRO_COM_T', 'PRO_COM', 'COMUNE', 'COMUNE_A',
#        'SIGLA_AUTOMOBILISTICA', 'POP_LEG', 'ANNO_CENSIMENTO', 'AREA_KMQ',
#        'ANNO_AREA', 'POP_RES', 'ANNO_POP_RES', 'anno_riferimento'],
#       dtype='str')

# %%
df_comuni.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 87327 entries, 0 to 87326
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0.1           87327 non-null  int64
#  1   Unnamed: 0             87327 non-null  int64
#  2   COD_RIP                87327 non-null  int64
#  3   COD_REG                87327 non-null  int64
#  4   COD_PROV_STORICO       87327 non-null  int64
#  5   COD_UTS                87327 non-null  int64
#  6   PRO_COM_T              87327 non-null  int64
#  7   PRO_COM                87327 non-null  int64
#  8   COMUNE                 87316 non-null  str
#  9   COMUNE_A               1361 non-null   str
#  10  SIGLA_AUTOMOBILISTICA  86315 non-null  str
#  11  POP_LEG                87327 non-null  int64
#  12  ANNO_CENSIMENTO        87327 non-null  int64
#  13  AREA_KMQ               87327 non-null  str
#  14  ANNO_AREA              87327 non-null  int64
# ...

# %%
#LAVORO SU UN DATASET DI LAVORO DIFFERENTE DALLA SORGENTE
df_comuni_EDA = df_comuni.copy()

# %%
df_comuni_EDA.head(2)
# Out:
#    Unnamed: 0.1  Unnamed: 0  COD_RIP  COD_REG  COD_PROV_STORICO  COD_UTS  \
# 0             0           0        1        1                 1      201
# 1             1           1        1        1                 1      201
#
#    PRO_COM_T  PRO_COM   COMUNE COMUNE_A SIGLA_AUTOMOBILISTICA  POP_LEG  \
# 0       1001     1001    Agliè      NaN                    TO     2644
# 1       1002     1002  Airasca      NaN                    TO     3819
#
#    ANNO_CENSIMENTO AREA_KMQ  ANNO_AREA  POP_RES  ANNO_POP_RES  \
# 0             2011  13,1462       2015     2701          2014
# 1             2011  15,7393       2015     3798          2014
#
#    anno_riferimento
# 0              2015
# 1              2015

# %%
# MI CONSERVO SOLO LE COLONNE CHE HO INDICATO DI INTERESSE
# Attenzione rimuovo anche il campo COD_RIP perchè lo prendo da COD_REG - UNA REGIONE PUò APPARTENERE 
# A UNA SOLO COD_RISP E QUINDI COD_RISP NON è LEGATO AL COMUNE
df_comuni_EDA = df_comuni_EDA[['anno_riferimento','COD_REG', 'COD_UTS', 'PRO_COM', 'COMUNE','AREA_KMQ','POP_RES']]

# %%
df_comuni_EDA['COD_REG'].unique()
# Out:
# array([ 1,  2,  7,  3,  4,  5,  6,  8, 11,  9, 10, 12, 15, 13, 14, 16, 17,
#        18, 19, 20])

# %%
df_comuni_EDA.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 87327 entries, 0 to 87326
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anno_riferimento  87327 non-null  int64
#  1   COD_REG           87327 non-null  int64
#  2   COD_UTS           87327 non-null  int64
#  3   PRO_COM           87327 non-null  int64
#  4   COMUNE            87316 non-null  str
#  5   AREA_KMQ          87327 non-null  str
#  6   POP_RES           87327 non-null  int64
# dtypes: int64(5), str(2)
# memory usage: 4.7 MB

# %%
# a) tipo dato corretto eccetto area kmq
# b) non sono presenti colonne nulle eccetto su comune desc

# %%
# indago su comune

df_comuni_EDA[df_comuni_EDA['COMUNE'].isna()].count()
# Out:
# anno_riferimento    11
# COD_REG             11
# COD_UTS             11
# PRO_COM             11
# COMUNE               0
# AREA_KMQ            11
# POP_RES             11
# dtype: int64

# %%
df_comuni_EDA[df_comuni_EDA['COMUNE'].isna()]['PRO_COM']
#PROBLEMA SOLO SUL COMUNE 1168 --> verifico sul set di dati degli incidenti
# IN TUTTI GLI ANNI E' VUOTO, FORSE UN VECCHIO COMUNE
# Out:
# 167      1168
# 8215     1168
# 16218    1168
# 24201    1168
# 32158    1168
# 40084    1168
# 47988    1168
# 55891    1168
# 63795    1168
# 71696    1168
# 79595    1168
# Name: PRO_COM, dtype: int64

# %%
# nr di casi da bonificare
df_comuni_EDA[df_comuni_EDA['COMUNE'].isna()]['PRO_COM'].count()
# Out:
# np.int64(11)

# %%
# nr casi non vuoti
df_comuni_EDA[~df_comuni_EDA['COMUNE'].isna()]['PRO_COM'].count()
# Out:
# np.int64(87316)

# %%
# totale record
df_comuni_EDA['PRO_COM'].count()
# totale = alla somma dei singoli casi contati prima
# Out:
# np.int64(87327)

# %%
# rimuovo i casi vuoiti , stessi in tutti i record 
df_comuni_EDA = df_comuni_EDA[~df_comuni_EDA['COMUNE'].isna()]

# %%
# totale record ripulito che deve essere uguale a quello non vuoto prima dell'unione
df_comuni_EDA['PRO_COM'].count()
# ok
# Out:
# np.int64(87316)

# %%
df_comuni_EDA["AREA_KMQ"].to_dict()
# Out:
# {0: '13,1462',
#  1: '15,7393',
#  2: '46,3315',
#  3: '11,7314',
#  4: '7,3796',
#  5: '17,8756',
#  6: '5,6261',
#  7: '11,9193',
#  8: '7,486',
#  9: '9,3085',
#  10: '38,8782',
#  11: '8,1668',
#  12: '23,2172',
#  13: '9,9605',
#  14: '7,0859',
#  15: '13,0063',
#  16: '4,5064',
#  17: '15,4054',
#  18: '62,7105',
#  19: '2,0289',
#  20: '12,8027',
#  21: '132,203',
#  22: '3,9864',
#  23: '6,7343',
#  24: '18,5979',
#  25: '94,0819',
#  26: '14,2234',
#  27: '14,3261',
#  28: '6,9648',
#  29: '13,4189',
#  30: '12,3712',
#  31: '4,9617',
#  32: '10,919',
#  33: '6,2914',
#  34: '22,7585',
#  35: '11,135',
#  36: '8,9504',
#  37: '5,5701',
#  38: '14,3592',
#  39: '12,5598',
#  40: '14,6868',
#  41: '5,476',
#  42: '5,0591',
#  43: '37,0661',
#  44: '8,0973',
#  45: '10,2312',
#  46: '39,4925',
#  47: '14,1314',
#  48: '11,0863',
#  49: '9,1318',
#  50: '11,8499',
#  51: '11,9505',
#  52: '11,1953',
#  53: '23,0319',
#  54: '16,4078',
#  55: '11,5371',
#  56: '10,2579',
# ...

# %%
#test di conversione
df_comuni_EDA["AREA_KMQ"].str.replace(',', '.').astype('float')
# Out:
# 0         13.1462
# 1         15.7393
# 2         46.3315
# 3         11.7314
# 4          7.3796
#            ...
# 87322    181.3947
# 87323    130.3596
# 87324     58.1781
# 87325     86.8137
# 87326     27.1943
# Name: AREA_KMQ, Length: 87316, dtype: float64

# %%
# sostituzione dato
df_comuni_EDA["AREA_KMQ"] = df_comuni_EDA["AREA_KMQ"].str.replace(',', '.')

# %%
#converto
df_comuni_EDA["AREA_KMQ"] = df_comuni_EDA.AREA_KMQ.astype(float)

# %%
#verifico
df_comuni_EDA["AREA_KMQ"].info()
# Out:
# <class 'pandas.Series'>
# Index: 87316 entries, 0 to 87326
# Series name: AREA_KMQ
# Non-Null Count  Dtype
# --------------  -----
# 87316 non-null  float64
# dtypes: float64(1)
# memory usage: 1.3 MB

# %%
df_comuni_EDA.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 87316 entries, 0 to 87326
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anno_riferimento  87316 non-null  int64
#  1   COD_REG           87316 non-null  int64
#  2   COD_UTS           87316 non-null  int64
#  3   PRO_COM           87316 non-null  int64
#  4   COMUNE            87316 non-null  str
#  5   AREA_KMQ          87316 non-null  float64
#  6   POP_RES           87316 non-null  int64
# dtypes: float64(1), int64(5), str(1)
# memory usage: 5.3 MB

# %%
#SALVO IL DATASET FINALE

pd_common.SalvaDataset(df_comuni_EDA, f"ElencoComuni",False)
# Out:
#       path completo file:  c:\progetto_dataanalyst\progettofinale\Analisi/ElencoComuni.csv
#          Il file 'c:\progetto_dataanalyst\progettofinale\Analisi/ElencoComuni.csv' esiste, per cui lo rimuovo
#       Il file salvato c:\progetto_dataanalyst\progettofinale\Analisi/ElencoComuni.csv
